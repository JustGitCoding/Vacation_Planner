# %%
# %matplotlib inline
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime
from scipy.stats import linregress

# %%
# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude & longitude coordinates
lats = np.random.uniform(-90.000, 90.000, size=1500)
lngs = np.random.uniform(-180.000, 180.000, size=1500)
# Zip together lat/long combos
lat_lngs = zip(lats, lngs)    # packs each pair of lats & lngs having the same index into a TUPLE
lat_lngs

# %%
# Save lat/long combos as a list
coordinates = list(lat_lngs)

# %%
# Create a list to hold cities we've identified
cities = []

# Identify nearest city for each lat/long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Add city to cities list - but only if it is not already included
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 627

# %%
# # What's wrong with my call??
# city = cities[50]
# city_url = url + "&q=" + cities[0].replace(" ","+")
# requests.get(city_url).json()

# %%
# Initialize empty lists to hold weather data
city_data = []

# Print the beginning of the logging.
print('Beginning Data Retrieval          ')
print('----------------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through all cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to record count
    record_count += 1
    try:
        # Parse JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        
        # Convert date to ISO format
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append city info into city_data_list
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Date': city_date})
        
    # If an error is experienced, skip that city
    except:
        print('City not found. Skipping', city)
        pass

# Indicate that Data Loading is Complete
print('----------------------------------')
print('Data Retrieval Complete           ')
print('----------------------------------')
# Out:
# Beginning Data Retrieval
# ----------------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping illoqqortoormiut
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | talaja
# Processing Record 4 of Set 1 | bengkulu
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | luderitz
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping taolanaro
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | nikolskoye
# Processing Record 11 of Set 1 | marcona
# City not found. Skipping marcona
# Processing Record 12 of Set 1 | bluff
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | katsuura
# Processing Record 15 of Set 1 | hirara
# Processing Record 16 of Set 1 | yellowknife
# Processing Record 17 of Set 1 | kenai
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | tiksi
# Processing Record 20 of Set 1 | georgetown
# Processing Record 21 of Set 1 | valparaiso
# Processing Record 22 of Set 1 | torbay
# Processing Record 23 of Set 1 | hithadhoo
# Processing Record 24 of Set 1 | axim
# Processing Record 25 of Set 1 | usinsk
# Processing Record 26 of Set 1 | atuona
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | jamestown
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping belushya guba
# Processing Record 30 of Set 1 | dongsheng
# Processing Record 31 of Set 1 | marawi
# Processing Record 32 of Set 1 | kautokeino
# Processing Record 33 of Set 1 | olafsvik
# Processing Record 34 of Set 1 | turka
# Processing Record 35 of Set 1 | sentyabrskiy
# City not found. Skipping sentyabrskiy
# Processing Record 36 of Set 1 | mar del plata
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | avarua
# Processing Record 39 of Set 1 | suez
# Processing Record 40 of Set 1 | saint-joseph
# Processing Record 41 of Set 1 | butaritari
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | khilok
# Processing Record 44 of Set 1 | noyabrsk
# Processing Record 45 of Set 1 | verkhnevilyuysk
# Processing Record 46 of Set 1 | nara
# Processing Record 47 of Set 1 | malanje
# Processing Record 48 of Set 1 | puerto ayora
# Processing Record 49 of Set 1 | te anau
# Processing Record 50 of Set 1 | sitka
# Processing Record 1 of Set 2 | eyl
# Processing Record 2 of Set 2 | vila velha
# Processing Record 3 of Set 2 | dicabisagan
# Processing Record 4 of Set 2 | port blair
# Processing Record 5 of Set 2 | watertown
# Processing Record 6 of Set 2 | tisul
# Processing Record 7 of Set 2 | korba
# Processing Record 8 of Set 2 | saleaula
# City not found. Skipping saleaula
# Processing Record 9 of Set 2 | nichlaul
# Processing Record 10 of Set 2 | raudeberg
# Processing Record 11 of Set 2 | upernavik
# Processing Record 12 of Set 2 | hamilton
# Processing Record 13 of Set 2 | mill valley
# Processing Record 14 of Set 2 | tasiilaq
# Processing Record 15 of Set 2 | kawalu
# Processing Record 16 of Set 2 | soyo
# Processing Record 17 of Set 2 | linxia
# Processing Record 18 of Set 2 | ancud
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | kostomuksha
# Processing Record 21 of Set 2 | barrow
# Processing Record 22 of Set 2 | halalo
# City not found. Skipping halalo
# Processing Record 23 of Set 2 | hilo
# Processing Record 24 of Set 2 | tessalit
# Processing Record 25 of Set 2 | los llanos de aridane
# Processing Record 26 of Set 2 | bundaberg
# Processing Record 27 of Set 2 | castro
# Processing Record 28 of Set 2 | beloha
# Processing Record 29 of Set 2 | barentsburg
# City not found. Skipping barentsburg
# Processing Record 30 of Set 2 | attawapiskat
# City not found. Skipping attawapiskat
# Processing Record 31 of Set 2 | iqaluit
# Processing Record 32 of Set 2 | saint-philippe
# Processing Record 33 of Set 2 | lorengau
# Processing Record 34 of Set 2 | luganville
# Processing Record 35 of Set 2 | palu
# Processing Record 36 of Set 2 | carbondale
# Processing Record 37 of Set 2 | vardo
# Processing Record 38 of Set 2 | mnogovershinnyy
# Processing Record 39 of Set 2 | ushuaia
# Processing Record 40 of Set 2 | las colinas
# Processing Record 41 of Set 2 | joaquim gomes
# Processing Record 42 of Set 2 | talnakh
# Processing Record 43 of Set 2 | sibu
# Processing Record 44 of Set 2 | guerrero negro
# Processing Record 45 of Set 2 | thompson
# Processing Record 46 of Set 2 | miri
# Processing Record 47 of Set 2 | labuan
# Processing Record 48 of Set 2 | tumannyy
# City not found. Skipping tumannyy
# Processing Record 49 of Set 2 | greenwood
# Processing Record 50 of Set 2 | merrill
# Processing Record 1 of Set 3 | hasaki
# Processing Record 2 of Set 3 | hermanus
# Processing Record 3 of Set 3 | kalianget
# Processing Record 4 of Set 3 | belen
# Processing Record 5 of Set 3 | bandarbeyla
# Processing Record 6 of Set 3 | ormara
# Processing Record 7 of Set 3 | flin flon
# Processing Record 8 of Set 3 | bubaque
# Processing Record 9 of Set 3 | the valley
# Processing Record 10 of Set 3 | east london
# Processing Record 11 of Set 3 | santa rita
# Processing Record 12 of Set 3 | dikson
# Processing Record 13 of Set 3 | chokurdakh
# Processing Record 14 of Set 3 | sabang
# Processing Record 15 of Set 3 | busselton
# Processing Record 16 of Set 3 | hobart
# Processing Record 17 of Set 3 | vaini
# Processing Record 18 of Set 3 | mehamn
# Processing Record 19 of Set 3 | brazzaville
# Processing Record 20 of Set 3 | reefton
# City not found. Skipping reefton
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | la ronge
# Processing Record 24 of Set 3 | luziania
# Processing Record 25 of Set 3 | padang
# Processing Record 26 of Set 3 | qaqortoq
# Processing Record 27 of Set 3 | chervone
# Processing Record 28 of Set 3 | tsihombe
# City not found. Skipping tsihombe
# Processing Record 29 of Set 3 | udachnyy
# Processing Record 30 of Set 3 | antigonish
# Processing Record 31 of Set 3 | lebu
# Processing Record 32 of Set 3 | sibiti
# Processing Record 33 of Set 3 | dunedin
# Processing Record 34 of Set 3 | mount gambier
# Processing Record 35 of Set 3 | erenhot
# Processing Record 36 of Set 3 | vao
# Processing Record 37 of Set 3 | isangel
# Processing Record 38 of Set 3 | cumaribo
# City not found. Skipping cumaribo
# Processing Record 39 of Set 3 | tawau
# Processing Record 40 of Set 3 | akdepe
# Processing Record 41 of Set 3 | mahebourg
# Processing Record 42 of Set 3 | negara
# Processing Record 43 of Set 3 | fevralsk
# City not found. Skipping fevralsk
# Processing Record 44 of Set 3 | severo-kurilsk
# Processing Record 45 of Set 3 | gangotri
# City not found. Skipping gangotri
# Processing Record 46 of Set 3 | kondoa
# Processing Record 47 of Set 3 | vallenar
# Processing Record 48 of Set 3 | sibolga
# Processing Record 49 of Set 3 | sao joao da barra
# Processing Record 50 of Set 3 | kristiinankaupunki
# Processing Record 1 of Set 4 | ahipara
# Processing Record 2 of Set 4 | domoni
# Processing Record 3 of Set 4 | stornoway
# Processing Record 4 of Set 4 | korla
# Processing Record 5 of Set 4 | ishigaki
# Processing Record 6 of Set 4 | tungkang
# City not found. Skipping tungkang
# Processing Record 7 of Set 4 | utiroa
# City not found. Skipping utiroa
# Processing Record 8 of Set 4 | bolungarvik
# City not found. Skipping bolungarvik
# Processing Record 9 of Set 4 | itarema
# Processing Record 10 of Set 4 | alofi
# Processing Record 11 of Set 4 | sabla
# Processing Record 12 of Set 4 | verkhnetulomskiy
# Processing Record 13 of Set 4 | cockburn town
# Processing Record 14 of Set 4 | fairbanks
# Processing Record 15 of Set 4 | susangerd
# Processing Record 16 of Set 4 | amursk
# Processing Record 17 of Set 4 | clyde river
# Processing Record 18 of Set 4 | kodiak
# Processing Record 19 of Set 4 | makakilo city
# Processing Record 20 of Set 4 | biak
# Processing Record 21 of Set 4 | coquimbo
# Processing Record 22 of Set 4 | la seyne-sur-mer
# Processing Record 23 of Set 4 | tura
# Processing Record 24 of Set 4 | devils lake
# Processing Record 25 of Set 4 | san patricio
# Processing Record 26 of Set 4 | kankaanpaa
# Processing Record 27 of Set 4 | natal
# Processing Record 28 of Set 4 | aasiaat
# Processing Record 29 of Set 4 | hami
# Processing Record 30 of Set 4 | khatanga
# Processing Record 31 of Set 4 | saldanha
# Processing Record 32 of Set 4 | klaksvik
# Processing Record 33 of Set 4 | rodrigues alves
# Processing Record 34 of Set 4 | sao filipe
# Processing Record 35 of Set 4 | san rafael
# Processing Record 36 of Set 4 | ostrovnoy
# Processing Record 37 of Set 4 | madhogarh
# Processing Record 38 of Set 4 | bambous virieux
# Processing Record 39 of Set 4 | pisco
# Processing Record 40 of Set 4 | nemuro
# Processing Record 41 of Set 4 | jalu
# Processing Record 42 of Set 4 | svetlogorsk
# Processing Record 43 of Set 4 | bethel
# Processing Record 44 of Set 4 | coronado
# Processing Record 45 of Set 4 | kasungu
# Processing Record 46 of Set 4 | camana
# Processing Record 47 of Set 4 | abalak
# Processing Record 48 of Set 4 | sorland
# Processing Record 49 of Set 4 | college
# Processing Record 50 of Set 4 | rudbar
# Processing Record 1 of Set 5 | port alfred
# Processing Record 2 of Set 5 | chuy
# Processing Record 3 of Set 5 | kurchum
# Processing Record 4 of Set 5 | farafangana
# Processing Record 5 of Set 5 | acapulco
# Processing Record 6 of Set 5 | arraial do cabo
# Processing Record 7 of Set 5 | kuryk
# Processing Record 8 of Set 5 | seryshevo
# Processing Record 9 of Set 5 | tarhunah
# City not found. Skipping tarhunah
# Processing Record 10 of Set 5 | zhigansk
# Processing Record 11 of Set 5 | port augusta
# Processing Record 12 of Set 5 | ribeira grande
# Processing Record 13 of Set 5 | kiomboi
# Processing Record 14 of Set 5 | namibe
# Processing Record 15 of Set 5 | nsanje
# Processing Record 16 of Set 5 | kruisfontein
# Processing Record 17 of Set 5 | mount isa
# Processing Record 18 of Set 5 | stromness
# Processing Record 19 of Set 5 | anamur
# Processing Record 20 of Set 5 | half moon bay
# Processing Record 21 of Set 5 | pljevlja
# Processing Record 22 of Set 5 | saint george
# Processing Record 23 of Set 5 | comodoro rivadavia
# Processing Record 24 of Set 5 | corrente
# Processing Record 25 of Set 5 | chandur bazar
# Processing Record 26 of Set 5 | sanlucar la mayor
# Processing Record 27 of Set 5 | longyearbyen
# Processing Record 28 of Set 5 | riyadh
# Processing Record 29 of Set 5 | calvinia
# Processing Record 30 of Set 5 | faya
# Processing Record 31 of Set 5 | nizhneyansk
# City not found. Skipping nizhneyansk
# Processing Record 32 of Set 5 | dwarka
# Processing Record 33 of Set 5 | manuk mangkaw
# Processing Record 34 of Set 5 | asau
# Processing Record 35 of Set 5 | broken hill
# Processing Record 36 of Set 5 | poya
# Processing Record 37 of Set 5 | zarubino
# Processing Record 38 of Set 5 | gigmoto
# Processing Record 39 of Set 5 | jiayuguan
# Processing Record 40 of Set 5 | rundu
# Processing Record 41 of Set 5 | butimanu
# Processing Record 42 of Set 5 | deolali
# Processing Record 43 of Set 5 | turbat
# Processing Record 44 of Set 5 | hambantota
# Processing Record 45 of Set 5 | praia da vitoria
# Processing Record 46 of Set 5 | mariental
# Processing Record 47 of Set 5 | anloga
# Processing Record 48 of Set 5 | souillac
# Processing Record 49 of Set 5 | havelock
# Processing Record 50 of Set 5 | waingapu
# Processing Record 1 of Set 6 | luau
# Processing Record 2 of Set 6 | bathsheba
# Processing Record 3 of Set 6 | sombrio
# Processing Record 4 of Set 6 | atherton
# Processing Record 5 of Set 6 | berlevag
# Processing Record 6 of Set 6 | kavieng
# Processing Record 7 of Set 6 | pacific grove
# Processing Record 8 of Set 6 | anito
# Processing Record 9 of Set 6 | charters towers
# Processing Record 10 of Set 6 | mpika
# Processing Record 11 of Set 6 | flinders
# Processing Record 12 of Set 6 | samalaeulu
# City not found. Skipping samalaeulu
# Processing Record 13 of Set 6 | kavaratti
# Processing Record 14 of Set 6 | andenes
# Processing Record 15 of Set 6 | bowen
# Processing Record 16 of Set 6 | ulaanbaatar
# Processing Record 17 of Set 6 | tazovskiy
# Processing Record 18 of Set 6 | muros
# Processing Record 19 of Set 6 | constitucion
# Processing Record 20 of Set 6 | mwinilunga
# Processing Record 21 of Set 6 | santa fe
# Processing Record 22 of Set 6 | palmer
# Processing Record 23 of Set 6 | sisimiut
# Processing Record 24 of Set 6 | beringovskiy
# Processing Record 25 of Set 6 | cape town
# Processing Record 26 of Set 6 | lebyazhye
# Processing Record 27 of Set 6 | rocha
# Processing Record 28 of Set 6 | olinda
# Processing Record 29 of Set 6 | lavrentiya
# Processing Record 30 of Set 6 | saskylakh
# Processing Record 31 of Set 6 | naze
# Processing Record 32 of Set 6 | airai
# Processing Record 33 of Set 6 | hervey bay
# Processing Record 34 of Set 6 | mogadishu
# Processing Record 35 of Set 6 | batagay
# Processing Record 36 of Set 6 | teguise
# Processing Record 37 of Set 6 | cape canaveral
# Processing Record 38 of Set 6 | cidreira
# Processing Record 39 of Set 6 | namatanai
# Processing Record 40 of Set 6 | saint-francois
# Processing Record 41 of Set 6 | christchurch
# Processing Record 42 of Set 6 | mackay
# Processing Record 43 of Set 6 | port macquarie
# Processing Record 44 of Set 6 | vangaindrano
# Processing Record 45 of Set 6 | lodja
# Processing Record 46 of Set 6 | ponta do sol
# Processing Record 47 of Set 6 | norman wells
# Processing Record 48 of Set 6 | sao jose da coroa grande
# Processing Record 49 of Set 6 | vostok
# Processing Record 50 of Set 6 | caconda
# Processing Record 1 of Set 7 | ouallam
# Processing Record 2 of Set 7 | mys shmidta
# City not found. Skipping mys shmidta
# Processing Record 3 of Set 7 | upata
# Processing Record 4 of Set 7 | mahanoro
# Processing Record 5 of Set 7 | tilichiki
# Processing Record 6 of Set 7 | marsh harbour
# Processing Record 7 of Set 7 | mutoko
# Processing Record 8 of Set 7 | sol-iletsk
# Processing Record 9 of Set 7 | jiazi
# Processing Record 10 of Set 7 | sagua la grande
# Processing Record 11 of Set 7 | nelson bay
# Processing Record 12 of Set 7 | kharitonovo
# Processing Record 13 of Set 7 | chiredzi
# Processing Record 14 of Set 7 | sabha
# Processing Record 15 of Set 7 | karwar
# Processing Record 16 of Set 7 | chemin grenier
# Processing Record 17 of Set 7 | lompoc
# Processing Record 18 of Set 7 | aban
# Processing Record 19 of Set 7 | bicas
# Processing Record 20 of Set 7 | byron bay
# Processing Record 21 of Set 7 | ola
# Processing Record 22 of Set 7 | esperance
# Processing Record 23 of Set 7 | tias
# Processing Record 24 of Set 7 | elko
# Processing Record 25 of Set 7 | yumen
# Processing Record 26 of Set 7 | dimitrovgrad
# Processing Record 27 of Set 7 | samusu
# City not found. Skipping samusu
# Processing Record 28 of Set 7 | jablonec nad jizerou
# Processing Record 29 of Set 7 | fort-de-france
# Processing Record 30 of Set 7 | abu samrah
# Processing Record 31 of Set 7 | goderich
# Processing Record 32 of Set 7 | maningrida
# Processing Record 33 of Set 7 | broome
# Processing Record 34 of Set 7 | beyneu
# Processing Record 35 of Set 7 | galveston
# Processing Record 36 of Set 7 | salalah
# Processing Record 37 of Set 7 | bonfim
# Processing Record 38 of Set 7 | faanui
# Processing Record 39 of Set 7 | tornio
# Processing Record 40 of Set 7 | komsomolskiy
# Processing Record 41 of Set 7 | sorvag
# City not found. Skipping sorvag
# Processing Record 42 of Set 7 | grand centre
# City not found. Skipping grand centre
# Processing Record 43 of Set 7 | carbonia
# Processing Record 44 of Set 7 | coihaique
# Processing Record 45 of Set 7 | mixtepec
# City not found. Skipping mixtepec
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | beinamar
# Processing Record 48 of Set 7 | yar-sale
# Processing Record 49 of Set 7 | sterling
# Processing Record 50 of Set 7 | lusambo
# Processing Record 1 of Set 8 | ust-maya
# Processing Record 2 of Set 8 | atambua
# Processing Record 3 of Set 8 | ixtapa
# Processing Record 4 of Set 8 | manado
# Processing Record 5 of Set 8 | sobolevo
# Processing Record 6 of Set 8 | maracacume
# Processing Record 7 of Set 8 | vestmannaeyjar
# Processing Record 8 of Set 8 | vaitupu
# City not found. Skipping vaitupu
# Processing Record 9 of Set 8 | raymond
# Processing Record 10 of Set 8 | clinton
# Processing Record 11 of Set 8 | copiapo
# Processing Record 12 of Set 8 | nan
# Processing Record 13 of Set 8 | port-gentil
# Processing Record 14 of Set 8 | hayrabolu
# Processing Record 15 of Set 8 | roald
# Processing Record 16 of Set 8 | methoni
# Processing Record 17 of Set 8 | andros town
# Processing Record 18 of Set 8 | batagay-alyta
# Processing Record 19 of Set 8 | nouadhibou
# Processing Record 20 of Set 8 | atar
# Processing Record 21 of Set 8 | steamboat springs
# Processing Record 22 of Set 8 | noumea
# Processing Record 23 of Set 8 | esparta
# Processing Record 24 of Set 8 | nishihara
# Processing Record 25 of Set 8 | el alto
# Processing Record 26 of Set 8 | kovur
# Processing Record 27 of Set 8 | ambon
# Processing Record 28 of Set 8 | xingyi
# Processing Record 29 of Set 8 | touros
# Processing Record 30 of Set 8 | grand river south east
# City not found. Skipping grand river south east
# Processing Record 31 of Set 8 | pangnirtung
# Processing Record 32 of Set 8 | manbij
# Processing Record 33 of Set 8 | taltal
# Processing Record 34 of Set 8 | pevek
# Processing Record 35 of Set 8 | bilma
# Processing Record 36 of Set 8 | grenada
# Processing Record 37 of Set 8 | padilla
# Processing Record 38 of Set 8 | megion
# Processing Record 39 of Set 8 | sainte-maxime
# Processing Record 40 of Set 8 | evensk
# Processing Record 41 of Set 8 | kadipur
# Processing Record 42 of Set 8 | jacareacanga
# Processing Record 43 of Set 8 | duz
# City not found. Skipping duz
# Processing Record 44 of Set 8 | karauzyak
# City not found. Skipping karauzyak
# Processing Record 45 of Set 8 | shunyi
# Processing Record 46 of Set 8 | naberera
# Processing Record 47 of Set 8 | port-cartier
# Processing Record 48 of Set 8 | san cristobal
# Processing Record 49 of Set 8 | fraserburgh
# Processing Record 50 of Set 8 | srednekolymsk
# Processing Record 1 of Set 9 | port lincoln
# Processing Record 2 of Set 9 | ontario
# Processing Record 3 of Set 9 | karaul
# City not found. Skipping karaul
# Processing Record 4 of Set 9 | ochakiv
# Processing Record 5 of Set 9 | huarmey
# Processing Record 6 of Set 9 | grand gaube
# Processing Record 7 of Set 9 | daoukro
# Processing Record 8 of Set 9 | humaita
# Processing Record 9 of Set 9 | uyuni
# Processing Record 10 of Set 9 | kjollefjord
# Processing Record 11 of Set 9 | show low
# Processing Record 12 of Set 9 | amderma
# City not found. Skipping amderma
# Processing Record 13 of Set 9 | avera
# Processing Record 14 of Set 9 | kampot
# Processing Record 15 of Set 9 | ahuimanu
# Processing Record 16 of Set 9 | ponoka
# Processing Record 17 of Set 9 | tucuman
# Processing Record 18 of Set 9 | buraydah
# Processing Record 19 of Set 9 | kaitangata
# Processing Record 20 of Set 9 | nampula
# Processing Record 21 of Set 9 | aksu
# Processing Record 22 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 23 of Set 9 | husavik
# Processing Record 24 of Set 9 | lubao
# Processing Record 25 of Set 9 | kasama
# Processing Record 26 of Set 9 | kavant
# City not found. Skipping kavant
# Processing Record 27 of Set 9 | bairiki
# Processing Record 28 of Set 9 | vanimo
# Processing Record 29 of Set 9 | ponta delgada
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | borodino
# Processing Record 32 of Set 9 | ginda
# Processing Record 33 of Set 9 | miles city
# Processing Record 34 of Set 9 | jonkoping
# Processing Record 35 of Set 9 | puro
# Processing Record 36 of Set 9 | lagoa
# Processing Record 37 of Set 9 | aklavik
# Processing Record 38 of Set 9 | yerofey pavlovich
# Processing Record 39 of Set 9 | provideniya
# Processing Record 40 of Set 9 | honiara
# Processing Record 41 of Set 9 | kutum
# Processing Record 42 of Set 9 | magadan
# Processing Record 43 of Set 9 | narsaq
# Processing Record 44 of Set 9 | burica
# City not found. Skipping burica
# Processing Record 45 of Set 9 | kirakira
# Processing Record 46 of Set 9 | thessalon
# Processing Record 47 of Set 9 | malwan
# City not found. Skipping malwan
# Processing Record 48 of Set 9 | katherine
# Processing Record 49 of Set 9 | palabuhanratu
# City not found. Skipping palabuhanratu
# Processing Record 50 of Set 9 | codajas
# Processing Record 1 of Set 10 | mezen
# Processing Record 2 of Set 10 | karak
# Processing Record 3 of Set 10 | baruun-urt
# Processing Record 4 of Set 10 | lensk
# Processing Record 5 of Set 10 | ballina
# Processing Record 6 of Set 10 | bac lieu
# Processing Record 7 of Set 10 | bafoulabe
# Processing Record 8 of Set 10 | mbaiki
# Processing Record 9 of Set 10 | ouahigouya
# Processing Record 10 of Set 10 | purgstall
# Processing Record 11 of Set 10 | lima
# Processing Record 12 of Set 10 | yuanping
# Processing Record 13 of Set 10 | xam nua
# Processing Record 14 of Set 10 | skagastrond
# City not found. Skipping skagastrond
# Processing Record 15 of Set 10 | palauig
# Processing Record 16 of Set 10 | grong
# Processing Record 17 of Set 10 | port elizabeth
# Processing Record 18 of Set 10 | ituverava
# Processing Record 19 of Set 10 | warqla
# City not found. Skipping warqla
# Processing Record 20 of Set 10 | pasighat
# Processing Record 21 of Set 10 | villa carlos paz
# Processing Record 22 of Set 10 | lamu
# Processing Record 23 of Set 10 | lincoln
# Processing Record 24 of Set 10 | dahuk
# Processing Record 25 of Set 10 | machiques
# Processing Record 26 of Set 10 | ambanja
# Processing Record 27 of Set 10 | turku
# Processing Record 28 of Set 10 | maceio
# Processing Record 29 of Set 10 | lashio
# Processing Record 30 of Set 10 | gat
# Processing Record 31 of Set 10 | mercedes
# Processing Record 32 of Set 10 | karpathos
# Processing Record 33 of Set 10 | bagdarin
# Processing Record 34 of Set 10 | kuusamo
# Processing Record 35 of Set 10 | pontianak
# Processing Record 36 of Set 10 | hobyo
# Processing Record 37 of Set 10 | raga
# Processing Record 38 of Set 10 | krasnik
# Processing Record 39 of Set 10 | puerto baquerizo moreno
# Processing Record 40 of Set 10 | menongue
# Processing Record 41 of Set 10 | codrington
# Processing Record 42 of Set 10 | porto velho
# Processing Record 43 of Set 10 | jinchang
# Processing Record 44 of Set 10 | cayenne
# Processing Record 45 of Set 10 | ipswich
# Processing Record 46 of Set 10 | kem
# Processing Record 47 of Set 10 | lahaina
# Processing Record 48 of Set 10 | moshenskoye
# Processing Record 49 of Set 10 | bombay
# Processing Record 50 of Set 10 | tuggurt
# City not found. Skipping tuggurt
# Processing Record 1 of Set 11 | lyngseidet
# Processing Record 2 of Set 11 | pathein
# Processing Record 3 of Set 11 | ouesso
# Processing Record 4 of Set 11 | boguchany
# Processing Record 5 of Set 11 | northam
# Processing Record 6 of Set 11 | mae hong son
# Processing Record 7 of Set 11 | qandala
# Processing Record 8 of Set 11 | szczytno
# Processing Record 9 of Set 11 | okhotsk
# Processing Record 10 of Set 11 | san pedro
# Processing Record 11 of Set 11 | severnyy
# Processing Record 12 of Set 11 | kuche
# City not found. Skipping kuche
# Processing Record 13 of Set 11 | sinazongwe
# Processing Record 14 of Set 11 | tumba
# Processing Record 15 of Set 11 | millau
# Processing Record 16 of Set 11 | palmdale
# Processing Record 17 of Set 11 | cap malheureux
# Processing Record 18 of Set 11 | mahibadhoo
# Processing Record 19 of Set 11 | karlskrona
# Processing Record 20 of Set 11 | nola
# Processing Record 21 of Set 11 | twentynine palms
# Processing Record 22 of Set 11 | whitehorse
# Processing Record 23 of Set 11 | koltsovo
# Processing Record 24 of Set 11 | poum
# Processing Record 25 of Set 11 | solovetskiy
# City not found. Skipping solovetskiy
# Processing Record 26 of Set 11 | dubbo
# Processing Record 27 of Set 11 | nedjo
# Processing Record 28 of Set 11 | iquitos
# Processing Record 29 of Set 11 | meadow lake
# Processing Record 30 of Set 11 | umzimvubu
# City not found. Skipping umzimvubu
# Processing Record 31 of Set 11 | rawson
# Processing Record 32 of Set 11 | mucuri
# Processing Record 33 of Set 11 | rio grande
# Processing Record 34 of Set 11 | carbonear
# Processing Record 35 of Set 11 | zhezkazgan
# Processing Record 36 of Set 11 | alugan
# Processing Record 37 of Set 11 | ust-nera
# Processing Record 38 of Set 11 | jardim
# Processing Record 39 of Set 11 | palmeirais
# Processing Record 40 of Set 11 | ayagoz
# Processing Record 41 of Set 11 | himora
# City not found. Skipping himora
# Processing Record 42 of Set 11 | portree
# Processing Record 43 of Set 11 | safaga
# Processing Record 44 of Set 11 | gumia
# Processing Record 45 of Set 11 | suzun
# Processing Record 46 of Set 11 | aitape
# Processing Record 47 of Set 11 | challapata
# Processing Record 48 of Set 11 | ahumada
# City not found. Skipping ahumada
# Processing Record 49 of Set 11 | jucas
# Processing Record 50 of Set 11 | buala
# Processing Record 1 of Set 12 | vila franca do campo
# Processing Record 2 of Set 12 | loukhi
# Processing Record 3 of Set 12 | ozgon
# City not found. Skipping ozgon
# Processing Record 4 of Set 12 | atchison
# Processing Record 5 of Set 12 | walvis bay
# Processing Record 6 of Set 12 | abu kamal
# Processing Record 7 of Set 12 | kegayli
# City not found. Skipping kegayli
# Processing Record 8 of Set 12 | nyurba
# Processing Record 9 of Set 12 | vidim
# Processing Record 10 of Set 12 | nanakuli
# Processing Record 11 of Set 12 | cairns
# Processing Record 12 of Set 12 | yerbogachen
# Processing Record 13 of Set 12 | victoria
# Processing Record 14 of Set 12 | keti bandar
# Processing Record 15 of Set 12 | zheleznogorsk
# Processing Record 16 of Set 12 | potam
# Processing Record 17 of Set 12 | podgornoye
# Processing Record 18 of Set 12 | chlorakas
# Processing Record 19 of Set 12 | tual
# Processing Record 20 of Set 12 | gao
# Processing Record 21 of Set 12 | meyungs
# City not found. Skipping meyungs
# Processing Record 22 of Set 12 | xiongzhou
# Processing Record 23 of Set 12 | purificacion
# Processing Record 24 of Set 12 | dinsor
# City not found. Skipping dinsor
# Processing Record 25 of Set 12 | kaeo
# Processing Record 26 of Set 12 | matagami
# Processing Record 27 of Set 12 | nanortalik
# Processing Record 28 of Set 12 | hualmay
# Processing Record 29 of Set 12 | arman
# Processing Record 30 of Set 12 | hay river
# Processing Record 31 of Set 12 | hovd
# Processing Record 32 of Set 12 | bulgan
# Processing Record 33 of Set 12 | ngunguru
# Processing Record 34 of Set 12 | abha
# Processing Record 35 of Set 12 | san policarpo
# Processing Record 36 of Set 12 | north bend
# Processing Record 37 of Set 12 | kushima
# Processing Record 38 of Set 12 | tabuk
# Processing Record 39 of Set 12 | yulara
# Processing Record 40 of Set 12 | itacoatiara
# Processing Record 41 of Set 12 | kailua
# Processing Record 42 of Set 12 | ocean city
# Processing Record 43 of Set 12 | pyu
# Processing Record 44 of Set 12 | colares
# Processing Record 45 of Set 12 | lolua
# City not found. Skipping lolua
# Processing Record 46 of Set 12 | lhokseumawe
# Processing Record 47 of Set 12 | yeppoon
# Processing Record 48 of Set 12 | bambanglipuro
# Processing Record 49 of Set 12 | haines junction
# Processing Record 50 of Set 12 | jishou
# Processing Record 1 of Set 13 | prince rupert
# Processing Record 2 of Set 13 | tuatapere
# Processing Record 3 of Set 13 | arlit
# Processing Record 4 of Set 13 | gallup
# Processing Record 5 of Set 13 | pangai
# Processing Record 6 of Set 13 | requena
# Processing Record 7 of Set 13 | pitsunda
# Processing Record 8 of Set 13 | san jose
# Processing Record 9 of Set 13 | road town
# Processing Record 10 of Set 13 | alamosa
# Processing Record 11 of Set 13 | saint anthony
# Processing Record 12 of Set 13 | piedras negras
# Processing Record 13 of Set 13 | tagbac
# Processing Record 14 of Set 13 | ciudad bolivar
# Processing Record 15 of Set 13 | portland
# Processing Record 16 of Set 13 | coxim
# Processing Record 17 of Set 13 | nantucket
# Processing Record 18 of Set 13 | betare oya
# Processing Record 19 of Set 13 | puerto escondido
# Processing Record 20 of Set 13 | leningradskiy
# Processing Record 21 of Set 13 | khash
# Processing Record 22 of Set 13 | north battleford
# Processing Record 23 of Set 13 | parfino
# Processing Record 24 of Set 13 | acari
# Processing Record 25 of Set 13 | juneau
# Processing Record 26 of Set 13 | acarau
# Processing Record 27 of Set 13 | harper
# ----------------------------------
# Data Retrieval Complete
# ----------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame & set order of columns in DF.
city_data_df = pd.DataFrame(city_data)
column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[column_order]

# Export data into CSV file
output_data_file = '../Resources/weather_data/cities.csv'
city_data_df.to_csv(output_data_file, index_label = 'City_ID')

# %%
# Extract relevant fields from DF
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
# Build scatterplot for latitude vs MAX TEMPERATURE
plt.scatter(lats, max_temps,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Max Temperature '+time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig1.png')

# %%
# Build scatterplot for latitude vs HUMIDITY
plt.scatter(lats, humidity,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Humidity '+time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig2.png')

# %%
# Build scatterplot for latitude vs CLOUDINESS
plt.scatter(lats, cloudiness,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Cloudiness '+time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig3.png')

# %%
# Build scatterplot for latitude vs WIND SPEED
plt.scatter(lats, wind_speed,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Wind Speed '+time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig4.png')

# %%
# Create a FUNCTION to perform linear regression on the weather data, plot regression line and print the equation
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):
    
    # Run regression on hemisphere weather data
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)
    
    # Calculate regression line 'y-values' from slope & intercept
    regress_values = x_values * slope + intercept
    
    # Save the line equation
    line_eq = 'y = ' + str(round(slope,2)) + 'x + ' + str(round(intercept,2))
    
    # Create scatterplot & plot regression line
    plt.scatter(x_values, y_values,)
    plt.plot(x_values, regress_values, 'r')
    
    # Print regression line equation
    plt.annotate(line_eq+f'\n r-value: {r_value:.2f}', text_coordinates, fontsize=15, color='r')
    plt.title(title)
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.show()

# %%
# Create DataFrame for NORTHERN hemisphere only
northern_hemi_df = city_data_df.loc[(city_data_df['Lat'] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df['Lat'] < 0)]

# %%
# Linear Regression on Northern Hemisphere - MAX TEMP
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere \nfor Maximum Temperature', 'Max Temp', (5, -25))

# %%
# Linear Regression on Southern Hemisphere - MAX TEMP
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere \nfor Maximum Temperature', 'Max Temp', (-30, 50))

# %%
# Linear Regression on Northern Hemisphere - HUMIDITY
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere \nfor Humidity', 'Humidity', (45,20))

# %%
# Linear Regression on Southern Hemisphere - HUMIDITY
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere \nfor Humidity', 'Humidity', (-23,12))

# %%
# Linear Regression on Northern Hemisphere - CLOUDINESS
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere \nfor Cloudiness', 'Cloudiness', (30,40))

# %%
# Linear Regression on Southern Hemisphere - CLOUDINESS
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere \nfor Cloudiness', 'Cloudiness', (-55,50))

# %%
# Linear Regression on Northern Hemisphere - WIND SPEED
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Northern Hemisphere \nfor Wind Speed', 'Wind Speed', (2,30))

# %%
# Linear Regression on Southern Hemisphere - WIND SPEED
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

# CALL the FUNCTION
plot_linear_regression(x_values, y_values, 'Linear Regression on Southern Hemisphere \nfor Wind Speed', 'Wind Speed', (-22,25))
