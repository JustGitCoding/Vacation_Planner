# %%
# %matplotlib inline
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
import requests
from config import weather_api_key
import time
from datetime import datetime

# %%
# Starting URL for Weather Map API call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create a set of random latitude & longitude coordinates
lats = np.random.uniform(-90.000, 90.000, size=1500)
lngs = np.random.uniform(-180.000, 180.000, size=1500)
# Zip together lat/long combos
lat_lngs = zip(lats, lngs)    # packs each pair of lats & lngs having the same index into a TUPLE
lat_lngs

# %%
# Save lat/long combos as a list
coordinates = list(lat_lngs)

# %%
# Create a list to hold cities we've identified
cities = []

# Identify nearest city for each lat/long combo
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # Add city to cities list - but only if it is not already included
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %%
# # What's wrong with my call??
# city = cities[50]
# city_url = url + "&q=" + cities[0].replace(" ","+")
# requests.get(city_url).json()

# %%
# Initialize empty lists to hold weather data
city_data = []

# Print the beginning of the logging.
print('Beginning Data Retrieval          ')
print('----------------------------------')

# Create counters
record_count = 1
set_count = 1

# Loop through all cities in our list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to record count
    record_count += 1
    try:
        # Parse JSON and retrieve data
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        
        # Convert date to ISO format
        city_date = datetime.utcfromtimestamp(city_weather['dt']).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append city info into city_data_list
        city_data.append({'City': city.title(),
                          'Lat': city_lat,
                          'Lng': city_lng,
                          'Max Temp': city_max_temp,
                          'Humidity': city_humidity,
                          'Cloudiness': city_clouds,
                          'Wind Speed': city_wind,
                          'Country': city_country,
                          'Date': city_date})
        
    # If an error is experienced, skip that city
    except:
        print('City not found. Skipping', city)
        pass

# Indicate that Data Loading is Complete
print('----------------------------------')
print('Data Retrieval Complete           ')
print('----------------------------------')
# Out:
# Beginning Data Retrieval
# ----------------------------------
# Processing Record 1 of Set 1 | raga
# Processing Record 2 of Set 1 | faya
# Processing Record 3 of Set 1 | sao paulo de olivenca
# Processing Record 4 of Set 1 | amderma
# City not found. Skipping amderma
# Processing Record 5 of Set 1 | albert lea
# Processing Record 6 of Set 1 | vila velha
# Processing Record 7 of Set 1 | port alfred
# Processing Record 8 of Set 1 | provideniya
# Processing Record 9 of Set 1 | saint-marc-des-carrieres
# Processing Record 10 of Set 1 | novyy urengoy
# Processing Record 11 of Set 1 | san patricio
# Processing Record 12 of Set 1 | bereda
# Processing Record 13 of Set 1 | antofagasta
# Processing Record 14 of Set 1 | kapaa
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | baglung
# Processing Record 17 of Set 1 | cape town
# Processing Record 18 of Set 1 | souillac
# Processing Record 19 of Set 1 | zhezkazgan
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | yellowknife
# Processing Record 23 of Set 1 | yulara
# Processing Record 24 of Set 1 | pangnirtung
# Processing Record 25 of Set 1 | bambous virieux
# Processing Record 26 of Set 1 | mitsamiouli
# Processing Record 27 of Set 1 | mabaruma
# Processing Record 28 of Set 1 | cidreira
# Processing Record 29 of Set 1 | lorengau
# Processing Record 30 of Set 1 | punta arenas
# Processing Record 31 of Set 1 | emerald
# Processing Record 32 of Set 1 | katherine
# Processing Record 33 of Set 1 | broome
# Processing Record 34 of Set 1 | pasighat
# Processing Record 35 of Set 1 | camacha
# Processing Record 36 of Set 1 | belushya guba
# City not found. Skipping belushya guba
# Processing Record 37 of Set 1 | ilulissat
# Processing Record 38 of Set 1 | lamar
# Processing Record 39 of Set 1 | bluff
# Processing Record 40 of Set 1 | bengkulu
# Processing Record 41 of Set 1 | ponta do sol
# Processing Record 42 of Set 1 | sorland
# Processing Record 43 of Set 1 | albany
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping taolanaro
# Processing Record 45 of Set 1 | kalemie
# Processing Record 46 of Set 1 | hobart
# Processing Record 47 of Set 1 | esperance
# Processing Record 48 of Set 1 | prince rupert
# Processing Record 49 of Set 1 | ushuaia
# Processing Record 50 of Set 1 | koupela
# Processing Record 1 of Set 2 | porto novo
# Processing Record 2 of Set 2 | broken hill
# Processing Record 3 of Set 2 | thompson
# Processing Record 4 of Set 2 | hirara
# Processing Record 5 of Set 2 | nuuk
# Processing Record 6 of Set 2 | jamestown
# Processing Record 7 of Set 2 | oliver
# Processing Record 8 of Set 2 | sagua la grande
# Processing Record 9 of Set 2 | fortuna
# Processing Record 10 of Set 2 | torbay
# Processing Record 11 of Set 2 | dikson
# Processing Record 12 of Set 2 | jibuti
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | guerrero negro
# Processing Record 15 of Set 2 | bowen
# Processing Record 16 of Set 2 | georgetown
# Processing Record 17 of Set 2 | sabha
# Processing Record 18 of Set 2 | samarai
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | sao gabriel da cachoeira
# Processing Record 21 of Set 2 | mount isa
# Processing Record 22 of Set 2 | kaspiyskiy
# Processing Record 23 of Set 2 | salalah
# Processing Record 24 of Set 2 | governador valadares
# Processing Record 25 of Set 2 | gat
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | alexandria
# Processing Record 28 of Set 2 | rio grande
# Processing Record 29 of Set 2 | monte alegre
# Processing Record 30 of Set 2 | puerto ayora
# Processing Record 31 of Set 2 | luderitz
# Processing Record 32 of Set 2 | carnarvon
# Processing Record 33 of Set 2 | porto velho
# Processing Record 34 of Set 2 | ambodifototra
# City not found. Skipping ambodifototra
# Processing Record 35 of Set 2 | kulhudhuffushi
# Processing Record 36 of Set 2 | barrow
# Processing Record 37 of Set 2 | salamina
# Processing Record 38 of Set 2 | mataura
# Processing Record 39 of Set 2 | ketchikan
# Processing Record 40 of Set 2 | vao
# Processing Record 41 of Set 2 | port lincoln
# Processing Record 42 of Set 2 | nelson bay
# Processing Record 43 of Set 2 | kavieng
# Processing Record 44 of Set 2 | tuktoyaktuk
# Processing Record 45 of Set 2 | miramar
# Processing Record 46 of Set 2 | srednekolymsk
# Processing Record 47 of Set 2 | belaya gora
# Processing Record 48 of Set 2 | tessalit
# Processing Record 49 of Set 2 | sentyabrskiy
# City not found. Skipping sentyabrskiy
# Processing Record 50 of Set 2 | puerto carreno
# Processing Record 1 of Set 3 | clyde river
# Processing Record 2 of Set 3 | mixtequilla
# City not found. Skipping mixtequilla
# Processing Record 3 of Set 3 | saldanha
# Processing Record 4 of Set 3 | longyearbyen
# Processing Record 5 of Set 3 | norman wells
# Processing Record 6 of Set 3 | vestbygda
# City not found. Skipping vestbygda
# Processing Record 7 of Set 3 | vaini
# Processing Record 8 of Set 3 | sechura
# Processing Record 9 of Set 3 | butaritari
# Processing Record 10 of Set 3 | porterville
# Processing Record 11 of Set 3 | cherskiy
# Processing Record 12 of Set 3 | attawapiskat
# City not found. Skipping attawapiskat
# Processing Record 13 of Set 3 | umm kaddadah
# Processing Record 14 of Set 3 | avarua
# Processing Record 15 of Set 3 | illoqqortoormiut
# City not found. Skipping illoqqortoormiut
# Processing Record 16 of Set 3 | chimbote
# Processing Record 17 of Set 3 | coihaique
# Processing Record 18 of Set 3 | bethel
# Processing Record 19 of Set 3 | nikolskoye
# Processing Record 20 of Set 3 | arraial do cabo
# Processing Record 21 of Set 3 | viligili
# City not found. Skipping viligili
# Processing Record 22 of Set 3 | la presa
# Processing Record 23 of Set 3 | berlevag
# Processing Record 24 of Set 3 | hofn
# Processing Record 25 of Set 3 | kumano
# Processing Record 26 of Set 3 | tautira
# Processing Record 27 of Set 3 | labutta
# City not found. Skipping labutta
# Processing Record 28 of Set 3 | hokitika
# Processing Record 29 of Set 3 | morondava
# Processing Record 30 of Set 3 | magadi
# Processing Record 31 of Set 3 | waingapu
# Processing Record 32 of Set 3 | qaqortoq
# Processing Record 33 of Set 3 | mutsamudu
# City not found. Skipping mutsamudu
# Processing Record 34 of Set 3 | barentsburg
# City not found. Skipping barentsburg
# Processing Record 35 of Set 3 | salinas
# Processing Record 36 of Set 3 | imbituba
# Processing Record 37 of Set 3 | sayyan
# Processing Record 38 of Set 3 | mys shmidta
# City not found. Skipping mys shmidta
# Processing Record 39 of Set 3 | humaita
# Processing Record 40 of Set 3 | bredasdorp
# Processing Record 41 of Set 3 | kalmunai
# Processing Record 42 of Set 3 | khatanga
# Processing Record 43 of Set 3 | winslow
# Processing Record 44 of Set 3 | laguna
# Processing Record 45 of Set 3 | udachnyy
# Processing Record 46 of Set 3 | hermanus
# Processing Record 47 of Set 3 | new norfolk
# Processing Record 48 of Set 3 | touros
# Processing Record 49 of Set 3 | atuona
# Processing Record 50 of Set 3 | maragogi
# Processing Record 1 of Set 4 | talnakh
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | bay roberts
# Processing Record 4 of Set 4 | leczyca
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping nizhneyansk
# Processing Record 6 of Set 4 | faanui
# Processing Record 7 of Set 4 | muroto
# Processing Record 8 of Set 4 | ribeira grande
# Processing Record 9 of Set 4 | campbell river
# Processing Record 10 of Set 4 | vaitupu
# City not found. Skipping vaitupu
# Processing Record 11 of Set 4 | nguiu
# City not found. Skipping nguiu
# Processing Record 12 of Set 4 | wajir
# Processing Record 13 of Set 4 | butwal
# Processing Record 14 of Set 4 | genthin
# Processing Record 15 of Set 4 | college
# Processing Record 16 of Set 4 | codrington
# Processing Record 17 of Set 4 | council bluffs
# Processing Record 18 of Set 4 | sao filipe
# Processing Record 19 of Set 4 | chokurdakh
# Processing Record 20 of Set 4 | shimoda
# Processing Record 21 of Set 4 | juneau
# Processing Record 22 of Set 4 | leningradskiy
# Processing Record 23 of Set 4 | barcelos
# Processing Record 24 of Set 4 | saint george
# Processing Record 25 of Set 4 | grand centre
# City not found. Skipping grand centre
# Processing Record 26 of Set 4 | nanortalik
# Processing Record 27 of Set 4 | san ramon de la nueva oran
# Processing Record 28 of Set 4 | port blair
# Processing Record 29 of Set 4 | repatriacion
# Processing Record 30 of Set 4 | tsihombe
# City not found. Skipping tsihombe
# Processing Record 31 of Set 4 | saskylakh
# Processing Record 32 of Set 4 | grand river south east
# City not found. Skipping grand river south east
# Processing Record 33 of Set 4 | nouadhibou
# Processing Record 34 of Set 4 | marcona
# City not found. Skipping marcona
# Processing Record 35 of Set 4 | ishigaki
# Processing Record 36 of Set 4 | halalo
# City not found. Skipping halalo
# Processing Record 37 of Set 4 | mantua
# Processing Record 38 of Set 4 | te karaka
# Processing Record 39 of Set 4 | mar del plata
# Processing Record 40 of Set 4 | hilo
# Processing Record 41 of Set 4 | bandarbeyla
# Processing Record 42 of Set 4 | linxia
# Processing Record 43 of Set 4 | chadan
# Processing Record 44 of Set 4 | ust-kuyga
# Processing Record 45 of Set 4 | kearney
# Processing Record 46 of Set 4 | geraldton
# Processing Record 47 of Set 4 | yuzhno-kurilsk
# Processing Record 48 of Set 4 | zaqatala
# Processing Record 49 of Set 4 | hami
# Processing Record 50 of Set 4 | maltahohe
# Processing Record 1 of Set 5 | saint-georges
# Processing Record 2 of Set 5 | margate
# Processing Record 3 of Set 5 | santa maria
# Processing Record 4 of Set 5 | clearfield
# Processing Record 5 of Set 5 | loiza
# Processing Record 6 of Set 5 | hong gai
# Processing Record 7 of Set 5 | angoram
# Processing Record 8 of Set 5 | paamiut
# Processing Record 9 of Set 5 | port elizabeth
# Processing Record 10 of Set 5 | chuy
# Processing Record 11 of Set 5 | wentzville
# Processing Record 12 of Set 5 | jurm
# Processing Record 13 of Set 5 | mahebourg
# Processing Record 14 of Set 5 | mungwi
# Processing Record 15 of Set 5 | grand gaube
# Processing Record 16 of Set 5 | kohima
# Processing Record 17 of Set 5 | port-gentil
# Processing Record 18 of Set 5 | acapulco
# Processing Record 19 of Set 5 | eskisehir
# Processing Record 20 of Set 5 | brus laguna
# Processing Record 21 of Set 5 | dasoguz
# Processing Record 22 of Set 5 | cabo san lucas
# Processing Record 23 of Set 5 | victoria
# Processing Record 24 of Set 5 | sitka
# Processing Record 25 of Set 5 | solsvik
# City not found. Skipping solsvik
# Processing Record 26 of Set 5 | progreso
# Processing Record 27 of Set 5 | mariental
# Processing Record 28 of Set 5 | ahipara
# Processing Record 29 of Set 5 | capinzal
# Processing Record 30 of Set 5 | chicama
# Processing Record 31 of Set 5 | miranorte
# City not found. Skipping miranorte
# Processing Record 32 of Set 5 | east london
# Processing Record 33 of Set 5 | beringovskiy
# Processing Record 34 of Set 5 | zhigalovo
# Processing Record 35 of Set 5 | marquette
# Processing Record 36 of Set 5 | zhangjiakou
# Processing Record 37 of Set 5 | taguatinga
# Processing Record 38 of Set 5 | alofi
# Processing Record 39 of Set 5 | safwah
# City not found. Skipping safwah
# Processing Record 40 of Set 5 | rafina
# Processing Record 41 of Set 5 | sinop
# Processing Record 42 of Set 5 | airai
# Processing Record 43 of Set 5 | butembo
# Processing Record 44 of Set 5 | riesi
# Processing Record 45 of Set 5 | sur
# Processing Record 46 of Set 5 | teyateyaneng
# Processing Record 47 of Set 5 | epe
# Processing Record 48 of Set 5 | ouesso
# Processing Record 49 of Set 5 | tilichiki
# Processing Record 50 of Set 5 | tha chang
# Processing Record 1 of Set 6 | mao
# Processing Record 2 of Set 6 | tonneins
# Processing Record 3 of Set 6 | pangkalanbuun
# Processing Record 4 of Set 6 | katsuura
# Processing Record 5 of Set 6 | oranjemund
# Processing Record 6 of Set 6 | tiksi
# Processing Record 7 of Set 6 | pevek
# Processing Record 8 of Set 6 | zeya
# Processing Record 9 of Set 6 | trincomalee
# Processing Record 10 of Set 6 | lavrentiya
# Processing Record 11 of Set 6 | burica
# City not found. Skipping burica
# Processing Record 12 of Set 6 | saint-philippe
# Processing Record 13 of Set 6 | nome
# Processing Record 14 of Set 6 | lasa
# Processing Record 15 of Set 6 | najran
# Processing Record 16 of Set 6 | zamosc
# Processing Record 17 of Set 6 | marawi
# Processing Record 18 of Set 6 | severo-kurilsk
# Processing Record 19 of Set 6 | kamenskoye
# City not found. Skipping kamenskoye
# Processing Record 20 of Set 6 | saint-louis
# Processing Record 21 of Set 6 | paita
# Processing Record 22 of Set 6 | piacabucu
# Processing Record 23 of Set 6 | tumannyy
# City not found. Skipping tumannyy
# Processing Record 24 of Set 6 | qui nhon
# Processing Record 25 of Set 6 | sataua
# City not found. Skipping sataua
# Processing Record 26 of Set 6 | kresttsy
# Processing Record 27 of Set 6 | rantauprapat
# Processing Record 28 of Set 6 | klaksvik
# Processing Record 29 of Set 6 | akureyri
# Processing Record 30 of Set 6 | saint-pierre
# Processing Record 31 of Set 6 | kabarnet
# Processing Record 32 of Set 6 | samusu
# City not found. Skipping samusu
# Processing Record 33 of Set 6 | koygorodok
# Processing Record 34 of Set 6 | huanren
# Processing Record 35 of Set 6 | kolosovka
# Processing Record 36 of Set 6 | san juan
# Processing Record 37 of Set 6 | shumskiy
# Processing Record 38 of Set 6 | kenai
# Processing Record 39 of Set 6 | melilla
# Processing Record 40 of Set 6 | sao raimundo das mangabeiras
# Processing Record 41 of Set 6 | ancud
# Processing Record 42 of Set 6 | tuatapere
# Processing Record 43 of Set 6 | darnah
# Processing Record 44 of Set 6 | vanino
# Processing Record 45 of Set 6 | vestmannaeyjar
# Processing Record 46 of Set 6 | mingaora
# Processing Record 47 of Set 6 | corrente
# Processing Record 48 of Set 6 | kamenka
# Processing Record 49 of Set 6 | chirilagua
# Processing Record 50 of Set 6 | bathsheba
# Processing Record 1 of Set 7 | warangal
# Processing Record 2 of Set 7 | zhigansk
# Processing Record 3 of Set 7 | port macquarie
# Processing Record 4 of Set 7 | veraval
# Processing Record 5 of Set 7 | coquimbo
# Processing Record 6 of Set 7 | north bend
# Processing Record 7 of Set 7 | zaysan
# Processing Record 8 of Set 7 | adrar
# Processing Record 9 of Set 7 | taloqan
# Processing Record 10 of Set 7 | honiara
# Processing Record 11 of Set 7 | flic en flac
# Processing Record 12 of Set 7 | dzerzhinsk
# Processing Record 13 of Set 7 | iskateley
# Processing Record 14 of Set 7 | oussouye
# Processing Record 15 of Set 7 | ostrovnoy
# Processing Record 16 of Set 7 | karaul
# City not found. Skipping karaul
# Processing Record 17 of Set 7 | bealanana
# Processing Record 18 of Set 7 | tigil
# Processing Record 19 of Set 7 | kavaratti
# Processing Record 20 of Set 7 | san cristobal
# Processing Record 21 of Set 7 | meadow lake
# Processing Record 22 of Set 7 | ozernovskiy
# Processing Record 23 of Set 7 | ivybridge
# Processing Record 24 of Set 7 | bamako
# Processing Record 25 of Set 7 | gornyak
# Processing Record 26 of Set 7 | kolpny
# Processing Record 27 of Set 7 | narsaq
# Processing Record 28 of Set 7 | constitucion
# Processing Record 29 of Set 7 | natal
# Processing Record 30 of Set 7 | kasongo-lunda
# Processing Record 31 of Set 7 | samdrup jongkhar
# Processing Record 32 of Set 7 | upernavik
# Processing Record 33 of Set 7 | pisco
# Processing Record 34 of Set 7 | hasaki
# Processing Record 35 of Set 7 | usinsk
# Processing Record 36 of Set 7 | comodoro rivadavia
# Processing Record 37 of Set 7 | amahai
# Processing Record 38 of Set 7 | kaoma
# Processing Record 39 of Set 7 | nakamura
# Processing Record 40 of Set 7 | toliary
# City not found. Skipping toliary
# Processing Record 41 of Set 7 | kaniama
# Processing Record 42 of Set 7 | zheleznodorozhnyy
# Processing Record 43 of Set 7 | kloulklubed
# Processing Record 44 of Set 7 | mookane
# Processing Record 45 of Set 7 | salekhard
# Processing Record 46 of Set 7 | flinders
# Processing Record 47 of Set 7 | praya
# Processing Record 48 of Set 7 | todos santos
# Processing Record 49 of Set 7 | camargo
# Processing Record 50 of Set 7 | kibala
# Processing Record 1 of Set 8 | hambantota
# Processing Record 2 of Set 8 | mullaitivu
# City not found. Skipping mullaitivu
# Processing Record 3 of Set 8 | zlatoustovsk
# City not found. Skipping zlatoustovsk
# Processing Record 4 of Set 8 | pacific grove
# Processing Record 5 of Set 8 | uruzgan
# Processing Record 6 of Set 8 | sorvag
# City not found. Skipping sorvag
# Processing Record 7 of Set 8 | dudinka
# Processing Record 8 of Set 8 | shingu
# Processing Record 9 of Set 8 | plettenberg bay
# Processing Record 10 of Set 8 | lagoa
# Processing Record 11 of Set 8 | kwinana
# Processing Record 12 of Set 8 | aswan
# Processing Record 13 of Set 8 | saleaula
# City not found. Skipping saleaula
# Processing Record 14 of Set 8 | abu dhabi
# Processing Record 15 of Set 8 | kiama
# Processing Record 16 of Set 8 | negombo
# Processing Record 17 of Set 8 | poltavka
# Processing Record 18 of Set 8 | okato
# Processing Record 19 of Set 8 | alghero
# Processing Record 20 of Set 8 | balabac
# Processing Record 21 of Set 8 | rosarno
# Processing Record 22 of Set 8 | busembatia
# Processing Record 23 of Set 8 | tura
# Processing Record 24 of Set 8 | labrea
# Processing Record 25 of Set 8 | sivas
# Processing Record 26 of Set 8 | conde
# Processing Record 27 of Set 8 | balsas
# Processing Record 28 of Set 8 | makakilo city
# Processing Record 29 of Set 8 | kruisfontein
# Processing Record 30 of Set 8 | moose factory
# Processing Record 31 of Set 8 | geneva
# Processing Record 32 of Set 8 | montecristo
# Processing Record 33 of Set 8 | sola
# Processing Record 34 of Set 8 | harper
# Processing Record 35 of Set 8 | mae sai
# Processing Record 36 of Set 8 | bilma
# Processing Record 37 of Set 8 | kysyl-syr
# Processing Record 38 of Set 8 | zhanatas
# City not found. Skipping zhanatas
# Processing Record 39 of Set 8 | carutapera
# Processing Record 40 of Set 8 | dunedin
# Processing Record 41 of Set 8 | senanga
# Processing Record 42 of Set 8 | susangerd
# Processing Record 43 of Set 8 | baghdad
# Processing Record 44 of Set 8 | matagami
# Processing Record 45 of Set 8 | maloy
# Processing Record 46 of Set 8 | sakaiminato
# Processing Record 47 of Set 8 | roma
# Processing Record 48 of Set 8 | rudbar
# Processing Record 49 of Set 8 | husavik
# Processing Record 50 of Set 8 | taoudenni
# Processing Record 1 of Set 9 | lompoc
# Processing Record 2 of Set 9 | cap malheureux
# Processing Record 3 of Set 9 | alyangula
# Processing Record 4 of Set 9 | gap
# Processing Record 5 of Set 9 | sam roi yot
# Processing Record 6 of Set 9 | zinder
# Processing Record 7 of Set 9 | buariki
# City not found. Skipping buariki
# Processing Record 8 of Set 9 | agutaya
# Processing Record 9 of Set 9 | dingle
# Processing Record 10 of Set 9 | vostok
# Processing Record 11 of Set 9 | cam ranh
# Processing Record 12 of Set 9 | uppsala
# Processing Record 13 of Set 9 | orangeburg
# Processing Record 14 of Set 9 | lalomanu
# City not found. Skipping lalomanu
# Processing Record 15 of Set 9 | manoel urbano
# Processing Record 16 of Set 9 | atherton
# Processing Record 17 of Set 9 | vanavara
# Processing Record 18 of Set 9 | iqaluit
# Processing Record 19 of Set 9 | banca
# Processing Record 20 of Set 9 | te anau
# Processing Record 21 of Set 9 | jiwani
# Processing Record 22 of Set 9 | killarney
# Processing Record 23 of Set 9 | minab
# Processing Record 24 of Set 9 | nadvoitsy
# Processing Record 25 of Set 9 | hamilton
# Processing Record 26 of Set 9 | batemans bay
# Processing Record 27 of Set 9 | koungou
# Processing Record 28 of Set 9 | portland
# Processing Record 29 of Set 9 | shakhtinsk
# Processing Record 30 of Set 9 | ixtapa
# Processing Record 31 of Set 9 | nishihara
# Processing Record 32 of Set 9 | port augusta
# Processing Record 33 of Set 9 | poum
# Processing Record 34 of Set 9 | chokwe
# Processing Record 35 of Set 9 | vila franca do campo
# Processing Record 36 of Set 9 | damoh
# Processing Record 37 of Set 9 | puri
# Processing Record 38 of Set 9 | gorno-chuyskiy
# City not found. Skipping gorno-chuyskiy
# Processing Record 39 of Set 9 | skeldon
# Processing Record 40 of Set 9 | idar
# Processing Record 41 of Set 9 | kesan
# Processing Record 42 of Set 9 | tete
# Processing Record 43 of Set 9 | sorong
# Processing Record 44 of Set 9 | nova odesa
# Processing Record 45 of Set 9 | los llanos de aridane
# Processing Record 46 of Set 9 | mandan
# Processing Record 47 of Set 9 | jaisalmer
# Processing Record 48 of Set 9 | roebourne
# Processing Record 49 of Set 9 | boke
# Processing Record 50 of Set 9 | fairbanks
# Processing Record 1 of Set 10 | yenangyaung
# Processing Record 2 of Set 10 | shamary
# Processing Record 3 of Set 10 | banjarmasin
# Processing Record 4 of Set 10 | lufilufi
# Processing Record 5 of Set 10 | ashland
# Processing Record 6 of Set 10 | zmeinogorsk
# Processing Record 7 of Set 10 | pereslavl-zalesskiy
# Processing Record 8 of Set 10 | tabou
# Processing Record 9 of Set 10 | timra
# Processing Record 10 of Set 10 | russell
# Processing Record 11 of Set 10 | namatanai
# Processing Record 12 of Set 10 | malwan
# City not found. Skipping malwan
# Processing Record 13 of Set 10 | sobolevo
# Processing Record 14 of Set 10 | semnan
# Processing Record 15 of Set 10 | kodiak
# Processing Record 16 of Set 10 | lata
# Processing Record 17 of Set 10 | shalya
# Processing Record 18 of Set 10 | bilibino
# Processing Record 19 of Set 10 | quelimane
# Processing Record 20 of Set 10 | grindavik
# Processing Record 21 of Set 10 | kaitangata
# Processing Record 22 of Set 10 | cayenne
# Processing Record 23 of Set 10 | hilton head island
# Processing Record 24 of Set 10 | velasco ibarra
# Processing Record 25 of Set 10 | miandrivazo
# Processing Record 26 of Set 10 | komsomolskiy
# Processing Record 27 of Set 10 | nosy varika
# Processing Record 28 of Set 10 | boa vista
# Processing Record 29 of Set 10 | malindi
# Processing Record 30 of Set 10 | ossora
# Processing Record 31 of Set 10 | basco
# Processing Record 32 of Set 10 | vila do maio
# Processing Record 33 of Set 10 | winona
# Processing Record 34 of Set 10 | nalut
# Processing Record 35 of Set 10 | unity
# Processing Record 36 of Set 10 | kangaatsiaq
# Processing Record 37 of Set 10 | port hardy
# Processing Record 38 of Set 10 | bitung
# Processing Record 39 of Set 10 | cheuskiny
# City not found. Skipping cheuskiny
# Processing Record 40 of Set 10 | lolua
# City not found. Skipping lolua
# Processing Record 41 of Set 10 | leh
# Processing Record 42 of Set 10 | indian head
# Processing Record 43 of Set 10 | waw
# Processing Record 44 of Set 10 | swan hill
# Processing Record 45 of Set 10 | columbus
# Processing Record 46 of Set 10 | sarangani
# Processing Record 47 of Set 10 | prokopyevsk
# Processing Record 48 of Set 10 | abeche
# Processing Record 49 of Set 10 | bosaso
# Processing Record 50 of Set 10 | galesong
# Processing Record 1 of Set 11 | zhovtneve
# Processing Record 2 of Set 11 | jiblah
# Processing Record 3 of Set 11 | alice springs
# Processing Record 4 of Set 11 | canyon
# Processing Record 5 of Set 11 | padang
# Processing Record 6 of Set 11 | soe
# Processing Record 7 of Set 11 | jakar
# Processing Record 8 of Set 11 | costa rica
# Processing Record 9 of Set 11 | hirtshals
# Processing Record 10 of Set 11 | enshi
# Processing Record 11 of Set 11 | den helder
# Processing Record 12 of Set 11 | tutoia
# Processing Record 13 of Set 11 | alotau
# City not found. Skipping alotau
# Processing Record 14 of Set 11 | la ronge
# Processing Record 15 of Set 11 | ouricuri
# Processing Record 16 of Set 11 | srandakan
# Processing Record 17 of Set 11 | borger
# Processing Record 18 of Set 11 | maracaibo
# Processing Record 19 of Set 11 | ust-kamchatsk
# City not found. Skipping ust-kamchatsk
# Processing Record 20 of Set 11 | kahului
# Processing Record 21 of Set 11 | roanoke
# Processing Record 22 of Set 11 | inverell
# Processing Record 23 of Set 11 | yuli
# Processing Record 24 of Set 11 | san matias
# Processing Record 25 of Set 11 | carballo
# Processing Record 26 of Set 11 | stokmarknes
# Processing Record 27 of Set 11 | inhambane
# Processing Record 28 of Set 11 | sept-iles
# Processing Record 29 of Set 11 | joshimath
# Processing Record 30 of Set 11 | kambove
# Processing Record 31 of Set 11 | kenitra
# Processing Record 32 of Set 11 | sao felix do xingu
# Processing Record 33 of Set 11 | aracoiaba da serra
# Processing Record 34 of Set 11 | falealupo
# City not found. Skipping falealupo
# Processing Record 35 of Set 11 | neiafu
# Processing Record 36 of Set 11 | kehl
# Processing Record 37 of Set 11 | fort nelson
# Processing Record 38 of Set 11 | elk city
# Processing Record 39 of Set 11 | brae
# Processing Record 40 of Set 11 | isangel
# Processing Record 41 of Set 11 | wanaka
# Processing Record 42 of Set 11 | floro
# Processing Record 43 of Set 11 | mildura
# Processing Record 44 of Set 11 | huilong
# Processing Record 45 of Set 11 | gouyave
# Processing Record 46 of Set 11 | muravlenko
# Processing Record 47 of Set 11 | khonuu
# City not found. Skipping khonuu
# Processing Record 48 of Set 11 | bolsheustikinskoye
# City not found. Skipping bolsheustikinskoye
# Processing Record 49 of Set 11 | bemidji
# Processing Record 50 of Set 11 | mjolby
# Processing Record 1 of Set 12 | mozarlandia
# Processing Record 2 of Set 12 | west wendover
# Processing Record 3 of Set 12 | jumla
# Processing Record 4 of Set 12 | stornoway
# Processing Record 5 of Set 12 | belmonte
# Processing Record 6 of Set 12 | poya
# Processing Record 7 of Set 12 | awjilah
# Processing Record 8 of Set 12 | nakanojo
# Processing Record 9 of Set 12 | chipinge
# Processing Record 10 of Set 12 | kostomuksha
# Processing Record 11 of Set 12 | sainte-anne-des-monts
# Processing Record 12 of Set 12 | havelock
# Processing Record 13 of Set 12 | macomer
# Processing Record 14 of Set 12 | norrtalje
# Processing Record 15 of Set 12 | ushumun
# Processing Record 16 of Set 12 | sangar
# Processing Record 17 of Set 12 | san rafael
# Processing Record 18 of Set 12 | dedza
# Processing Record 19 of Set 12 | kijang
# Processing Record 20 of Set 12 | genc
# Processing Record 21 of Set 12 | rafai
# Processing Record 22 of Set 12 | loandjili
# Processing Record 23 of Set 12 | road town
# Processing Record 24 of Set 12 | namibe
# Processing Record 25 of Set 12 | bubaque
# Processing Record 26 of Set 12 | nioro
# Processing Record 27 of Set 12 | mareeba
# Processing Record 28 of Set 12 | tazovskiy
# Processing Record 29 of Set 12 | yelovo
# Processing Record 30 of Set 12 | asau
# Processing Record 31 of Set 12 | kilindoni
# Processing Record 32 of Set 12 | pimentel
# Processing Record 33 of Set 12 | rijeka
# Processing Record 34 of Set 12 | ramnagar
# Processing Record 35 of Set 12 | mayo
# Processing Record 36 of Set 12 | yetkul
# Processing Record 37 of Set 12 | abu samrah
# Processing Record 38 of Set 12 | rosetta
# Processing Record 39 of Set 12 | ulladulla
# Processing Record 40 of Set 12 | manokwari
# Processing Record 41 of Set 12 | san jose de guanipa
# Processing Record 42 of Set 12 | ondjiva
# Processing Record 43 of Set 12 | okhotsk
# Processing Record 44 of Set 12 | crotone
# Processing Record 45 of Set 12 | utinga
# Processing Record 46 of Set 12 | nassjo
# Processing Record 47 of Set 12 | san luis
# Processing Record 48 of Set 12 | mayumba
# Processing Record 49 of Set 12 | kidal
# Processing Record 50 of Set 12 | baruun-urt
# Processing Record 1 of Set 13 | kelo
# Processing Record 2 of Set 13 | grafton
# Processing Record 3 of Set 13 | datong
# Processing Record 4 of Set 13 | nha trang
# ----------------------------------
# Data Retrieval Complete
# ----------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame & set order of columns in DF.
city_data_df = pd.DataFrame(city_data)
column_order = ['City', 'Country', 'Date', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed']
city_data_df = city_data_df[column_order]

# Export data into CSV file
output_data_file = '../Resources/weather_data/cities.csv'
city_data_df.to_csv(output_data_file, index_label = 'City_ID')

# %%
# Extract relevant fields from DF
lats = city_data_df['Lat']
max_temps = city_data_df['Max Temp']
humidity = city_data_df['Humidity']
cloudiness = city_data_df['Cloudiness']
wind_speed = city_data_df['Wind Speed']

# %%
# Build scatterplot for latitude vs MAX TEMPERATURE
plt.scatter(lats, max_temps,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Max Temperature '+time.strftime('%x'))
plt.ylabel('Max Temperature (F)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig1.png')

# %%
# Build scatterplot for latitude vs HUMIDITY
plt.scatter(lats, humidity,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Humidity '+time.strftime('%x'))
plt.ylabel('Humidity (%)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig2.png')

# %%
# Build scatterplot for latitude vs CLOUDINESS
plt.scatter(lats, cloudiness,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Cloudiness '+time.strftime('%x'))
plt.ylabel('Cloudiness (%)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig3.png')

# %%
# Build scatterplot for latitude vs WIND SPEED
plt.scatter(lats, wind_speed,
            edgecolor='k', linewidths=1, marker='o',
            alpha=0.8, label='Cities')

# Formatting
plt.title(f'City Latitude vs. Wind Speed '+time.strftime('%x'))
plt.ylabel('Wind Speed (mph)')
plt.xlabel('Latitude')
plt.grid()

# Save the figure
plt.savefig('../Analysis/Fig4.png')
